# %%
from selenium import webdriver
import os
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import requests

options = Options()
options.add_argument('--incognito')
driver = webdriver.Chrome(options=options)
 
for page in range(1, 15):
    url = f'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles?page={page}'
    driver.get(url)
    nuorodos = driver.find_elements(By.CLASS_NAME, 'product-image-container')
    for nuoroda in nuorodos:
        href = nuoroda.get_attribute('href')
        with open('nuotodos.txt', 'a+') as failas:
            failas.write(f'{href}\n')

# %%
options = Options()
options.add_argument('--incognito')
driver = webdriver.Chrome(options=options)
with open('nuotodos.txt', 'r') as failas:
    nuorodos = failas.readlines()
print(nuorodos)

for nuoroda in nuorodos:
    nuoroda = nuoroda.replace('\n', '')
    driver.get(nuoroda)
    nuotraukos = driver.find_elements(By.CLASS_NAME, 'c-galllery-slide--image')
    for nuotrauka in nuotraukos:
        src = nuotrauka.get_attribute('scr')
        print(src)
# Out:
# ['https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-r200bkw?id=3867245\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/beko-moc20100wfb?id=62600633\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/beko-moc20100bfb?id=62600643\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-yc-mg01e-c?id=31940272\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/hisense-h20moms4?id=58534383\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/esperanza-eko009?id=73363786\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/beko-moc201102w?id=53369459\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/samsung-me83x?id=4968190\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/samsung-ge83mbal?id=3743468\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-yc-mg01e-s?id=26383255\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-yc-ms01e-b?id=31939327\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/esperanza-eko011w?id=73363841\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/hisense-h20mowp1?id=58534398\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/samsung-ms23k3614ak?id=30971686\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/lg-mh6535gis?id=24944365\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/beko-mgf20210b?id=27333182\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/hisense-h20mobp1?id=58534368\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/esperanza-eko011k?id=73740081\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/gorenje-mo20e1s?id=30133131\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/samsung-ge83xxeo?id=3776360\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/hisense-h20momp1?id=58534358\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/beko-moc201002w?id=57543483\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/lg-ms23necbw?id=24944370\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/bosch-bfr634gb1?id=5627490\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/beko-moc20100sfb?id=62600653\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/lg-ms2535gib?id=24944360\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/gorenje-mo-4250-cli?id=5301862\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/candy-cmw20smw?id=70352366\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/whirlpool-mwp303m?id=20593080\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/candy-cmxg20dr?id=13331880\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/girmi-fm2105?id=28890225\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/whirlpool-wmf200gnb?id=33723731\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/samsung-ms23k3513awba?id=24333895\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/samsung-ge83x?id=33821961\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-yc-ms02e-c?id=46736139\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/hisense-h20mows4?id=58534393\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-yc-mg01e-w?id=57312068\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/sharp-yc-ms31e-s?id=45978273\n', 'https://pigu.lt/lt/buitine-technika-elektronika/mikrobangu-krosneles/toshiba-mwp-mm20pwh?id=46145588\n', 'ht ...

# %%
options = Options()
options.add_argument('--incognito')
driver = webdriver.Chrome(options=options)
photos_dir = 'mokrobanges'
if not os.path.exists(photos_dir):
    os.makedirs(photos_dir)
with open('nuorodos.txt', 'r') as failas:
    nuorodos = failas.readlines()
# print(nuorodos)
for idx, nuoroda in enumerate(nuorodos):
    nuoroda = nuoroda.replace('\n', '')
    driver.get(nuoroda)
    nuotraukos = driver.find_elements(By.CLASS_NAME, 'c-gallery-slide--image')
    for i, nuotrauka in enumerate(nuotraukos):
        src = nuotrauka.get_attribute('src')
        img_data = requests.get(src).content
        img_name = f'{idx}_{i}.jpg'
        img_path = os.path.join(photos_dir, img_name)
        with open(img_path, 'wb') as h:
            h.write(img_data)
        print(f'Issaugota {img_name} nuotrauka')
driver.quit()

# %%
from selenium import webdriver
import os
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import requests
options = Options()
options.add_argument('--incognito')
driver = webdriver.Chrome(options=options)
for page in range(1, 11):
    url = f'https://pigu.lt/lt/buitine-technika-elektronika/orkaites?page={page}'
    driver.get(url)
    nuorodos = driver.find_elements(By.CLASS_NAME, 'product-image-container')
    for nuoroda in nuorodos:
        href = nuoroda.get_attribute('href')
        with open('nuorodos1.txt', 'a+') as failas:
            failas.write(f'{href}\n')

# %%
options = Options()
options.add_argument('--incognito')
driver = webdriver.Chrome(options=options)
photos_dir = 'orkaites'
if not os.path.exists(photos_dir):
    os.makedirs(photos_dir)
with open('nuorodos1.txt', 'r') as failas:
    nuorodos = failas.readlines()
# print(nuorodos)
for idx, nuoroda in enumerate(nuorodos):
    nuoroda = nuoroda.replace('\n', '')
    driver.get(nuoroda)
    nuotraukos = driver.find_elements(By.CLASS_NAME, 'c-gallery-slide--image')
    for i, nuotrauka in enumerate(nuotraukos):
        src = nuotrauka.get_attribute('src')
        img_data = requests.get(src).content
        img_name = f'{idx}_{i}.jpg'
        img_path = os.path.join(photos_dir, img_name)
        with open(img_path, 'wb') as h:
            h.write(img_data)
        print(f'Issaugota {img_name} nuotrauka')
driver.quit()
