# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 

X = np.random.rand(100, 1)
y = X ** 2
print(X)
print(y)

model = LinearRegression()
model.fit(X,y)

plt.scatter(X,y)
plt.plot(X, model.predict(X))
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linijinė regresija')
plt.show()
# Out:
# [[0.04311697]
#  [0.16370263]
#  [0.11627833]
#  [0.67515335]
#  [0.4294933 ]
#  [0.7064665 ]
#  [0.37806399]
#  [0.79160447]
#  [0.00939468]
#  [0.33962368]
#  [0.1120599 ]
#  [0.99790638]
#  [0.97823977]
#  [0.64816315]
#  [0.88600347]
#  [0.60274906]
#  [0.15401474]
#  [0.69967606]
#  [0.19408187]
#  [0.34159971]
#  [0.04285441]
#  [0.88338625]
#  [0.73847831]
#  [0.39277819]
#  [0.48988469]
#  [0.9516891 ]
#  [0.08882148]
#  [0.57586659]
#  [0.37137017]
#  [0.14212162]
#  [0.12537587]
#  [0.45571641]
#  [0.07475946]
#  [0.62203416]
#  [0.31021154]
#  [0.6607257 ]
#  [0.7821824 ]
#  [0.58724934]
#  [0.66458122]
#  [0.39786736]
#  [0.90560312]
#  [0.35527854]
#  [0.30513504]
#  [0.15649554]
#  [0.0276215 ]
#  [0.77783373]
#  [0.8908231 ]
#  [0.04336709]
#  [0.0045306 ]
#  [0.39042821]
#  [0.7539263 ]
#  [0.57025428]
#  [0.43416637]
#  [0.86467794]
#  [0.30445284]
#  [0.55431559]
#  [0.52634179]
#  [0.97609061]
#  [0.69346137]
#  [0.09929041]
#  [0.05957261]
#  [0.38949659]
# ...

# %%
import pandas as pd 

df = pd.read_csv('autoscrap_1-200.csv')

kainos = df['k']
kainos.to_csv('kainos.csv')

# %%
from  sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

kainos = df['k']
data = df[['Variklis', 'Rida', 'Gamybos_metai']]

data['Gamybos_metai'] =  data['Gamybos_metai'].str.replace('-','')
# print(data['Gamybos_metai'])
data['Rida'] = data['Rida'].str.replace('km','')
data['Rida'] = data['Rida'].str.replace(' ','')
# data['kw'] = data['Variklis'].str.split('.,').iloc(axis=1)
data['kW'] = data['Variklis'].str.extract(r'(\d+) kW')[0]

reikalingi_data = data[['kW','Rida', 'Gamybos_metai']]

reikalingi_data.to_csv('data.csv')

X_train, X_test, y_train, y_test = train_test_split(reikalingi_data, kainos)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred =  model.predict(X_test)

plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],[y_test.min(), y_test.max()])
plt.show()
# Out:
# C:\Users\edita\AppData\Local\Temp\ipykernel_27316\1127584409.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gamybos_metai'] =  data['Gamybos_metai'].str.replace('-','')
# C:\Users\edita\AppData\Local\Temp\ipykernel_27316\1127584409.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace('km','')
# C:\Users\edita\AppData\Local\Temp\ipykernel_27316\1127584409.py:14: SettingWithCopyWarning:
# ...

# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt 

df = pd.read_csv('autoscrap_1-200.csv')

kainos = df['k']
kainos.to_csv('kainos.csv')


kainos = df['k']
data = df[['Variklis', 'Rida', 'Gamybos_metai' ]]

data['Gamybos_metai'] = data['Gamybos_metai'].str.replace("-","")
data['Rida'] = data['Rida'].str.replace("km","")
data['Rida'] = data['Rida'].str.replace(" ","")
data['Rida'] = data['Rida'].str.replace("Nenurodyta","1")
data['kW'] = data['Variklis'].str.extract(r'(\d+) kW')[0]



reikalinga_data = data[['kW', 'Rida', 'Gamybos_metai']]

reikalinga_data.to_csv('data.csv')

X_train, X_test, Y_train, Y_test = train_test_split(reikalinga_data, kainos)

model = LinearRegression()
model.fit(X_train, Y_train)

y_pred = model.predict(X_test)
plt.scatter(Y_test, y_pred)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()])
plt.show()
# Out:
# C:\Users\edita\AppData\Local\Temp\ipykernel_27316\641046089.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gamybos_metai'] = data['Gamybos_metai'].str.replace("-","")
# C:\Users\edita\AppData\Local\Temp\ipykernel_27316\641046089.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace("km","")
# C:\Users\edita\AppData\Local\Temp\ipykernel_27316\641046089.py:18: SettingWithCopyWarning:
# ...
