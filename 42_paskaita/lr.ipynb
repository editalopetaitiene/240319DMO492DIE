# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 

X = np.random.rand(100, 1)
y = X ** 2
print(X)
print(y)

model = LinearRegression()
model.fit(X,y)

plt.scatter(X,y)
plt.plot(X, model.predict(X))
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linijinė regresija')
plt.show()
# Out:
# [[0.04311697]
#  [0.16370263]
#  [0.11627833]
#  [0.67515335]
#  [0.4294933 ]
#  [0.7064665 ]
#  [0.37806399]
#  [0.79160447]
#  [0.00939468]
#  [0.33962368]
#  [0.1120599 ]
#  [0.99790638]
#  [0.97823977]
#  [0.64816315]
#  [0.88600347]
#  [0.60274906]
#  [0.15401474]
#  [0.69967606]
#  [0.19408187]
#  [0.34159971]
#  [0.04285441]
#  [0.88338625]
#  [0.73847831]
#  [0.39277819]
#  [0.48988469]
#  [0.9516891 ]
#  [0.08882148]
#  [0.57586659]
#  [0.37137017]
#  [0.14212162]
#  [0.12537587]
#  [0.45571641]
#  [0.07475946]
#  [0.62203416]
#  [0.31021154]
#  [0.6607257 ]
#  [0.7821824 ]
#  [0.58724934]
#  [0.66458122]
#  [0.39786736]
#  [0.90560312]
#  [0.35527854]
#  [0.30513504]
#  [0.15649554]
#  [0.0276215 ]
#  [0.77783373]
#  [0.8908231 ]
#  [0.04336709]
#  [0.0045306 ]
#  [0.39042821]
#  [0.7539263 ]
#  [0.57025428]
#  [0.43416637]
#  [0.86467794]
#  [0.30445284]
#  [0.55431559]
#  [0.52634179]
#  [0.97609061]
#  [0.69346137]
#  [0.09929041]
#  [0.05957261]
#  [0.38949659]
#  [0.18865119]
#  [0.39807887]
#  [0.5268925 ]
#  [0.13337508]
#  [0.24850801]
#  [0.96181961]
#  [0.04617802]
#  [0.96045102]
#  [0.01951149]
#  [0.69941854]
#  [0.02975543]
#  [0.57882083]
#  [0.04883661]
#  [0.89469076]
#  [0.0653894 ]
#  [0.58666979]
#  [0.78357335]
#  [0.36190492]
#  [0.60775072]
#  [0.71396073]
#  [0.54522918]
#  [0.69053809]
#  [0.65740904]
#  [0.93083838]
#  [0.58188717]
#  [0.72680449]
#  [0.8080135 ]
#  [0.79880288]
#  [0.19150314]
#  [0.82593736]
#  [0.91218713]
#  [0.07255604]
#  [0.8044653 ]
#  [0.93755639]
#  [0.71160227]
#  [0.52417601]
#  [0.92282826]
#  [0.66760191]]
# [[1.85907318e-03]
#  [2.67985498e-02]
#  [1.35206507e-02]
#  [4.55832050e-01]
#  [1.84464494e-01]
#  [4.99094921e-01]
#  [1.42932379e-01]
#  [6.26637642e-01]
#  [8.82599460e-05]
#  [1.15344244e-01]
#  [1.25574218e-02]
#  [9.95817153e-01]
#  [9.56953051e-01]
#  [4.20115467e-01]
#  [7.85002147e-01]
#  [3.63306429e-01]
#  [2.37205391e-02]
#  [4.89546583e-01]
#  [3.76677735e-02]
#  [1.16690361e-01]
#  [1.83650067e-03]
#  [7.80371275e-01]
#  [5.45350217e-01]
#  [1.54274703e-01]
#  [2.39987006e-01]
#  [9.05712146e-01]
#  [7.88925572e-03]
#  [3.31622335e-01]
#  [1.37915805e-01]
#  [2.01985537e-02]
#  [1.57191085e-02]
#  [2.07677442e-01]
#  [5.58897736e-03]
#  [3.86926495e-01]
#  [9.62311985e-02]
#  [4.36558452e-01]
#  [6.11809304e-01]
#  [3.44861784e-01]
#  [4.41668204e-01]
#  [1.58298436e-01]
#  [8.20117016e-01]
#  [1.26222839e-01]
#  [9.31073908e-02]
#  [2.44908526e-02]
#  [7.62947194e-04]
#  [6.05025308e-01]
#  [7.93565802e-01]
#  [1.88070441e-03]
#  [2.05263214e-05]
#  [1.52434186e-01]
#  [5.68404860e-01]
#  [3.25189945e-01]
#  [1.88500438e-01]
#  [7.47667944e-01]
#  [9.26915292e-02]
#  [3.07265774e-01]
#  [2.77035682e-01]
#  [9.52752886e-01]
#  [4.80888672e-01]
#  [9.85858606e-03]
#  [3.54889594e-03]
#  [1.51707597e-01]
#  [3.55892723e-02]
#  [1.58466786e-01]
#  [2.77615712e-01]
#  [1.77889114e-02]
#  [6.17562328e-02]
#  [9.25096962e-01]
#  [2.13240940e-03]
#  [9.22466152e-01]
#  [3.80698156e-04]
#  [4.89186299e-01]
#  [8.85385854e-04]
#  [3.35033552e-01]
#  [2.38501460e-03]
#  [8.00471553e-01]
#  [4.27577366e-03]
#  [3.44181445e-01]
#  [6.13987192e-01]
#  [1.30975174e-01]
#  [3.69360938e-01]
#  [5.09739923e-01]
#  [2.97274859e-01]
#  [4.76842851e-01]
#  [4.32186652e-01]
#  [8.66460091e-01]
#  [3.38592682e-01]
#  [5.28244769e-01]
#  [6.52885820e-01]
#  [6.38086048e-01]
#  [3.66734536e-02]
#  [6.82172519e-01]
#  [8.32085365e-01]
#  [5.26437840e-03]
#  [6.47164417e-01]
#  [8.79011985e-01]
#  [5.06377794e-01]
#  [2.74760494e-01]
#  [8.51611990e-01]
#  [4.45692308e-01]]

# %%
import pandas as pd 

df = pd.read_csv('autoscrap_1-200.csv')

kainos = df['k']
kainos.to_csv('kainos.csv')

# %%
data = df[['Variklis', 'Rida', 'Gamybos_metai']]
data['Gamybos_metai'] =  data['Gamybos_metai'].str.replace('-','')
# print(data['Gamybos_metai'])
data['Rida'] = data['Rida'].str.replace('km','')
data['Rida'] = data['Rida'].str.replace(' ','')
# data['kw'] = data['Variklis'].str.split('.,').iloc(axis=1)
data['kW'] = data['kW'].str.extract(r'(\d+) kW')[0]
reikalingi_data = data[['kW','Rida', 'Gamybos_metai']]

# for metai in data['Gamybos_metai']:
#     print(metai.replace('-',''))

reikalingi_data.to_csv('data.csv')
# Out:
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\4255958560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gamybos_metai'] =  data['Gamybos_metai'].str.replace('-','')
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\4255958560.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace('km','')
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\4255958560.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace(' ','')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\edita\Documents\KURSAI\240319DMO492DIE\mokymai\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'kW'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 7
#       5 data['Rida'] = data['Rida'].str.replace(' ','')
#       6 # data['kw'] = data['Variklis'].str.split('.,').iloc(axis=1)
# ----> 7 data['kW'] = data['kW'].str.extract(r'(\d+) kW')[0]
#       8 reikalingi_data = data[['kW','Rida', 'Gamybos_metai']]
#      10 # for metai in data['Gamybos_metai']:
#      11 #     print(metai.replace('-',''))
#
# File c:\Users\edita\Documents\KURSAI\240319DMO492DIE\mokymai\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\edita\Documents\KURSAI\240319DMO492DIE\mokymai\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'kW'

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

df = pd.read_csv('autoscrap_1-200.csv')

kainos = df['k']
kainos.to_csv('kainos.csv')


kainos = df['k']
data = df[['Variklis', 'Rida', 'Gamybos_metai' ]]

data['Gamybos_metai'] = data['Gamybos_metai'].str.replace("-","")
data['Rida'] = data['Rida'].str.replace("km","")
data['Rida'] = data['Rida'].str.replace(" ","")
data['Rida'] = data['Rida'].str.replace("Nenurodyta","1")
data['kW'] = data['Variklis'].str.extract(r'(\d+) kW')[0]



reikalinga_data = data[['kW', 'Rida', 'Gamybos_metai']]

reikalinga_data.to_csv('data.csv')

X_train, X_test, Y_train, Y_test = train_test_split(reikalinga_data, kainos)

model = LinearRegression()
model.fit(X_train, Y_train)

y_pred = model.predict(X_test)
plt.scatter(Y_test, y_pred)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()])
plt.show()
# Out:
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\1601838264.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gamybos_metai'] = data['Gamybos_metai'].str.replace("-","")
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\1601838264.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace("km","")
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\1601838264.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace(" ","")
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\1601838264.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rida'] = data['Rida'].str.replace("Nenurodyta","1")
# C:\Users\edita\AppData\Local\Temp\ipykernel_29576\1601838264.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['kW'] = data['Variklis'].str.extract(r'(\d+) kW')[0]
