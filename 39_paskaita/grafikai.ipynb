# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(20000, 80000, 50, endpoint=False)
y = np.random.uniform(20000, 80000, 50)

plt.plot(x, y)
plt.xlabel('X ašis')
plt.ylabel('Y ašis')
plt.title('Bandomasis grafikas')
plt.grid(True)
plt.show()
