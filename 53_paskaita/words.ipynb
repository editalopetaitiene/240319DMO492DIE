# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from keras.utils import to_categorical
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LMTS, Dense

# data = 'cia yra pradinis tekstas, veliau jo turesime daugiau'
with open("tekstas.txt", "r") as f:
  data = f.read()

tokenizer = Tokenizer() # sukuriame tokenizer objektą, kuris konvertuos teksta i skaitinius zodziu indeksus
tokenizer.fit_on_texts([data])  # mokome tokenizer su duomenimis
seqeunces = tokenizer.texts_to_sequences([data])[0]

vocab_size = len(tokenizer.word_index)+1

sequence_length = 5 
x = []
y = []

for i in range(sequence_length, len(seqeunces)):
    x.append(seqeunces[i-sequence_length:i])
    y.append(seqeunces[i])

x = np.array(x)
y = to_categorical(y, num_classes=vocab_size)

model = Sequential([
    Embedding(vocab_size, 50, input_length=sequence_length),
    LSTM(128),
    Dense(vocab_size, activation= 'softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy')
model.fit(x, y, epochs=50)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 5
#       3 import numpy as np
#       4 from tensorflow.keras.models import Sequential
# ----> 5 from tensorflow.keras.layers import Embedding, LMTS, Dense
#       7 # data = 'cia yra pradinis tekstas, veliau jo turesime daugiau'
#       8 with open("tekstas.txt", "r") as f:
#
# ImportError: cannot import name 'LMTS' from 'tensorflow.keras.layers' (c:\Users\edita\Documents\KURSAI\240319DMO492DIE\mokymai\Lib\site-packages\keras\_tf_keras\keras\layers\__init__.py)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

with open("tekstas.txt", "r", encoding='utf-8') as f:
  data = f.read()

tokenizer = Tokenizer() # sukuriame tokenizer objekta, kuris konvertuos teksta i skaitinius zodziu indeksus
tokenizer.fit_on_texts([data]) # mokome tokenizer su duomenimis
seqeunces = tokenizer.texts_to_sequences([data])[0]

vocab_size = len(tokenizer.word_index) + 1 # deklaruojame kiek zodziu mes turesime savo zodyne, jo veliau reikes nurodant isejimo galimybes

sequence_length = 5
x = []
y = []

for i in range(sequence_length, len(seqeunces)): # uzpildome sarasus zodziu sekomis ir zodziais, einanciais po ju
    x.append(seqeunces[i-sequence_length:i])
    y.append(seqeunces[i])

x = np.array(x) # konvertuojame x i matrica
y = to_categorical(y, num_classes=vocab_size)


model = Sequential([
    Embedding(vocab_size, 50, input_length=sequence_length),
    LSTM(128),
    Dense(vocab_size, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy')
model.fit(x, y, epochs=50)
# Out:
# c:\Users\edita\Documents\KURSAI\240319DMO492DIE\mokymai\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 7.4459
# Epoch 2/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 6.7896
# Epoch 3/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.6058
# Epoch 4/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.3714
# Epoch 5/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.1006
# Epoch 6/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.7805
# Epoch 7/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 5.4777
# Epoch 8/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 5.1487
# Epoch 9/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 4.9051
# Epoch 10/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 4.5497
# Epoch 11/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 4.2181
# Epoch 12/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9167
# Epoch 13/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 3.6203
# Epoch 14/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.3353
# Epoch 15/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.0674
# Epoch 16/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.7790
# Epoch 17/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.5400
# Epoch 18/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.2955
# Epoch 19/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.0693
# Epoch 20/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.8604
# Epoch 21/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.6673
# Epoch 22/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.5265
# Epoch 23/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3205
# Epoch 24/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.2262
# Epoch 25/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.0849
# Epoch 26/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.9679
# Epoch 27/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.8675
# Epoch 28/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.7654
# Epoch 29/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.6770
# Epoch 30/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5963
# Epoch 31/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.5292
# Epoch 32/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4950
# Epoch 33/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4209
# Epoch 34/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3711
# Epoch 35/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3384
# Epoch 36/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.3043
# Epoch 37/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2612
# Epoch 38/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2299
# Epoch 39/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2160
# Epoch 40/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1867
# Epoch 41/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1772
# Epoch 42/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1503
# Epoch 43/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1429
# Epoch 44/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1244
# Epoch 45/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1134
# Epoch 46/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1076
# Epoch 47/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1012
# Epoch 48/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0921
# Epoch 49/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0806
# Epoch 50/50
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0799

# %%
pradinis_tekstas = 'Latvijos valstybė yra nepriklausoma demokratinė respublika'

for _ in range(50):
    words_list = tokenizer.texts_to_sequences([pradinis_tekstas])[0]
    spejimo_sequence = np.array(words_list[-sequence_length:])
    x = np.expand_dims(spejimo_sequence, axis=0)
    predicted = model.predict(x, verbose=0)
    predicted_index = np.argmax(predicted, axis=1)[0]
    word = tokenizer.index_word[predicted_index]
    pradinis_tekstas += ' ' + word
print(pradinis_tekstas)
# Out:
# Latvijos valstybė yra nepriklausoma demokratinė respublika 2 straipsnis lietuvos valstybę kuria tauta suverenitetas priklauso tautai 3 straipsnis niekas negali varžyti ar riboti tautos suvereniteto savintis visai tautai priklausančių suverenių galių rinkliavas ir kiekvienas pilietis turi teisę priešintis bet kam kas prievarta kėsinasi į lietuvos valstybės nepriklausomybę teritorijos vientisumą konstitucinę santvarką 4 straipsnis aukščiausią suverenią galią tauta
